# %% [markdown]
# #  ML model that will predict likelihood of getting H1B approved
#
# ### Goal of the Project
#
# The goal of my project is to answer the following question: Is it possible to predict if an H1B application will be Certified or not given the selected company sponsor/job title/duration?
#
#
# ### Variables
#
# The project will focus on Company sponsor (Employers), Job Title, process Duration, salaries to start of. Note that to calculate the Duration, Decision Date and Case submitted date are used.
#
# ### Sample Date
#
# From the original data (650K observations), a random sample of 7K observations was drawn for the purpose of performing the analysis

# %%
# %matplotlib inline

import pandas as pd
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import seaborn as sns
import pylab
import bokeh.plotting as bkp
from mpl_toolkits.axes_grid1 import make_axes_locatable

# %%
data_eda = pd.read_excel("/Users/sheikita/Desktop/data/H-1B_EDAco.xlsx")

# %%
data_eda.head(20)
# Out:
#            CASE_NUMBER CASE_STATUS CASE_SUBMITTED DECISION_DATE   VISA_CLASS  \
# 0   I-200-18026-338377   CERTIFIED     2018-01-29    2018-02-02         H-1B
# 1   I-200-17296-353451   CERTIFIED     2017-10-23    2017-10-27         H-1B
# 2   I-200-18242-524477   CERTIFIED     2018-08-30    2018-09-06         H-1B
# 3   I-200-18243-850522   CERTIFIED     2018-08-31    2018-09-07         H-1B
# 4   I-200-18142-939501   CERTIFIED     2018-05-22    2018-05-29         H-1B
# 5   I-200-18121-552858   CERTIFIED     2018-05-01    2018-05-07         H-1B
# 6   I-200-18215-849606   CERTIFIED     2018-08-03    2018-08-09         H-1B
# 7   I-201-17339-472823   CERTIFIED     2017-12-08    2017-12-14  H-1B1 Chile
# 8   I-200-18233-239931   CERTIFIED     2018-08-21    2018-08-27         H-1B
# 9   I-200-18059-006093   CERTIFIED     2018-02-28    2018-03-06         H-1B
# 10  I-200-18107-783286   CERTIFIED     2018-04-18    2018-04-24         H-1B
# 11  I-200-18095-871087   CERTIFIED     2018-04-05    2018-04-11         H-1B
# 12  I-200-18057-019597   CERTIFIED     2018-02-26    2018-03-02         H-1B
# 13  I-200-18065-583678   CERTIFIED     2018-03-06    2018-03-12         H-1B
# 14  I-200-18024-890131   CERTIFIED     2018-01-24    2018-01-30         H-1B
# 15  I-200-18060-517421   CERTIFIED     2018-03-02    2018-03-08         H-1B
# 16  I-200-18025-163902   CERTIFIED     2018-03-05    2018-03-09         H-1B
# 17  I-200-18058-501771   CERTIFIED     2018-03-05    2018-03-09         H-1B
# 18  I-200-18062-732579      DENIED     2018-03-05    2018-03-07         H-1B
# 19  I-200-18064-452947   CERTIFIED     2018-03-05    2018-03-09         H-1B
#
#    EMPLOYMENT_START_DATE EMPLOYMENT_END_DATE  \
# 0             2018-07-28          2021-07-27
# 1             2017-11-06          2020-11-06
# 2             2018-09-10          2021-09-09
# 3             2018-09-07          2021-09-06
# 4             2018-05-29          2021-05-28
# 5             2018-05-02          2018-10-26
# 6             2018-08-11          2021-08-11
# 7             2017-12-08          2019-06-07
# 8             2018-09-05          2021-09-04
# 9             2018-05-15          2021-05-15
# 10            2018-06-01          2021-05-31
# 11            2018-04-12          2021-04-11
# 12            2018-08-23          2021-08-22
# 13            2018-09-05          2021-09-04
# 14            2018-07-26          2021-07-25
# 15            2018-08-28          2021-08-27
# 16            2018-09-01          2021-08-30
# 17            2018-09-01          2021-08-31
# 18            2018-09-04          2021-09-03
# 19            2018-09-01          2021-09-01
#
#                              EMPLOYER_NAME EMPLOYER_BUSINESS_DBA  \
# 0                    MICROSOFT CORPORATION                   NaN
# 1                   ERNST & YOUNG U.S. LLP                   NaN
# 2                             LOGIXHUB LLC                   NaN
# 3                         ECLOUD LABS,INC.                   NaN
# 4                                OBERON IT                   NaN
# 5                            ICONSOFT INC.                   NaN
# 6   COGNIZANT TECHNOLOGY SOLUTIONS US CORP                   NaN
# 7                         ISHI SYSTEMS INC                   NaN
# 8                        WB SOLUTIONS, LLC                   NaN
# 9                  INFOSTRETCH CORPORATION                   NaN
# 10                    THE ESAB GROUP, INC.                   NaN
# 11        LARSEN & TOUBRO INFOTECH LIMITED                   NaN
# 12       TATA CONSULTANCY SERVICES LIMITED                   NaN
# 13                ACRO SERVICE CORPORATION                   NaN
# 14           TECH MAHINDRA (AMERICAS),INC.                   NaN
# 15               VERIZON DATA SERVICES LLC                   NaN
# 16                   SUNRISE BOULEVARD LLC                   NaN
# 17                             MODNE, INC.                   NaN
# 18           CORBINS SERVICE ELECTRIC, LLC                   NaN
# 19         THERAVANCE BIOPHARMA U.S., INC.  THERAVANCE BIOPHARMA
#
#                             EMPLOYER_ADDRESS        ...         H1B_DEPENDENT  \
# 0                            1 MICROSOFT WAY        ...                     N
# 1                            200 PLAZA DRIVE        ...                     N
# 2                           320 DECKER DRIVE        ...                     N
# 3                          120 S WOOD AVENUE        ...                     Y
# 4                      1404 W WALNUT HILL LN        ...                     Y
# 5             101 CAMBRIDGE STREET SUITE 360        ...                     Y
# 6                         211 QUALITY CIRCLE        ...                     Y
# 7                          185 HUDSON STREET        ...                   NaN
# 8                        7320 E FLETCHER AVE        ...                     Y
# 9        3200 PATRICK HENRY DRIVE, SUITE 250        ...                     Y
# 10                       181 E. EVANS STREET        ...                     N
# 11  2035 LINCOLN HIGHWAY, EDISON SQUARE WEST        ...                     Y
# 12                  9201 CORPORATE BOULEVARD        ...                     Y
# 13                    39209 W. SIX MILE ROAD        ...                     N
# 14                        1001 DURHAM AVENUE        ...                     Y
# 15                          600 HIDDEN RIDGE        ...                     N
# 16                           128 LINCOLN ST.        ...                     N
# 17              13915 CERRITOS CORPORATE DR.        ...                     N
# 18                       4829 S. 38TH STREET        ...                     N
# 19                          901 GATEWAY BLVD        ...                     N
#
#    WILLFUL_VIOLATOR SUPPORT_H1B LABOR_CON_AGREE PUBLIC_DISCLOSURE_LOCATION  \
# 0                 N         NaN             NaN                        NaN
# 1                 N         NaN             NaN                        NaN
# 2                 N         NaN             NaN                        NaN
# 3                 N           Y               Y                        NaN
# 4                 N           Y             NaN                        NaN
# 5                 N           Y             NaN                        NaN
# 6                 N           Y             NaN                        NaN
# 7               NaN         NaN             NaN                        NaN
# 8                 N           Y               Y                        NaN
# 9                 N           Y               Y                        NaN
# 10                N         NaN             NaN                        NaN
# 11                N           Y             NaN                        NaN
# 12                N           Y             NaN                        NaN
# 13                N         NaN               Y                        NaN
# 14                N           Y               Y                        NaN
# 15                N         NaN             NaN                        NaN
# 16                N         NaN             NaN                        NaN
# 17                N         NaN             NaN                        NaN
# 18                N         NaN               Y                        NaN
# 19                N         NaN             NaN                        NaN
#
#           WORKSITE_CITY  WORKSITE_COUNTY WORKSITE_STATE WORKSITE_POSTAL_CODE  \
# 0               REDMOND             KING             WA                98052
# 1           SANTA CLARA         SAN JOSE             CA                95110
# 2                IRVING           DALLAS             TX                75062
# 3            BIRMINGHAM           SHELBY             AL                35244
# 4               SUNRISE          BROWARD             FL                33323
# 5          JACKSONVILLE     DUVAL COUNTY             FL                32202
# 6          OWINGS MILLS        BALTIMORE             MD                21117
# 7           JERSEY CITY           HUDSON             NJ                07311
# 8            ALPHARETTA           FULTON             GA                30005
# 9            PLEASANTON          ALAMEDA             CA                94588
# 10              HANOVER             YORK             PA                17331
# 11     LONG ISLAND CITY           QUEENS             NY                11101
# 12             ST. PAUL           RAMSEY             MN                55112
# 13          ALBUQUERQUE       BERNALILLO             NM                87108
# 14           SOUTHFIELD          OAKLAND             MI                48034
# 15               IRVING           DALLAS             TX                75038
# 16               BOSTON          SUFFOLK             MA                02111
# 17             CERRITOS      LOS ANGELES             CA                90703
# 18              PHOENIX         MARICOPA             AZ                85040
# 19  SOUTH SAN FRANCISCO        SAN MATEO             CA                94080
#
#    ORIGINAL_CERT_DATE
# 0                 NaT
# 1                 NaT
# 2                 NaT
# 3                 NaT
# 4                 NaT
# 5                 NaT
# 6                 NaT
# 7                 NaT
# 8                 NaT
# 9                 NaT
# 10                NaT
# 11                NaT
# 12                NaT
# 13                NaT
# 14                NaT
# 15                NaT
# 16                NaT
# 17                NaT
# 18                NaT
# 19                NaT
#
# [20 rows x 52 columns]

# %%
data_eda.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7001 entries, 0 to 7000
# Data columns (total 52 columns):
# CASE_NUMBER                    7001 non-null object
# CASE_STATUS                    7001 non-null object
# CASE_SUBMITTED                 7001 non-null datetime64[ns]
# DECISION_DATE                  7001 non-null datetime64[ns]
# VISA_CLASS                     7001 non-null object
# EMPLOYMENT_START_DATE          7000 non-null datetime64[ns]
# EMPLOYMENT_END_DATE            7000 non-null datetime64[ns]
# EMPLOYER_NAME                  7001 non-null object
# EMPLOYER_BUSINESS_DBA          791 non-null object
# EMPLOYER_ADDRESS               7001 non-null object
# EMPLOYER_CITY                  7001 non-null object
# EMPLOYER_STATE                 7001 non-null object
# EMPLOYER_POSTAL_CODE           7001 non-null object
# EMPLOYER_COUNTRY               7001 non-null object
# EMPLOYER_PROVINCE              39 non-null object
# EMPLOYER_PHONE                 7001 non-null int64
# EMPLOYER_PHONE_EXT             354 non-null float64
# AGENT_REPRESENTING_EMPLOYER    6999 non-null object
# AGENT_ATTORNEY_NAME            7001 non-null object
# AGENT_ATTORNEY_CITY            5560 non-null object
# AGENT_ATTORNEY_STATE           5420 non-null object
# JOB_TITLE                      7001 non-null object
# SOC_CODE                       6999 non-null object
# SOC_NAME                       6999 non-null object
# NAICS_CODE                     7001 non-null int64
# TOTAL_WORKERS                  7001 non-null int64
# NEW_EMPLOYMENT                 7001 non-null int64
# CONTINUED_EMPLOYMENT           7001 non-null int64
# CHANGE_PREVIOUS_EMPLOYMENT     7001 non-null int64
# NEW_CONCURRENT_EMP             7001 non-null int64
# CHANGE_EMPLOYER                7001 non-null int64
# AMENDED_PETITION               7001 non-null int64
# FULL_TIME_POSITION             7001 non-null object
# PREVAILING_WAGE                7000 non-null float64
# PW_UNIT_OF_PAY                 6997 non-null object
# PW_WAGE_LEVEL                  3167 non-null object
# PW_SOURCE                      6998 non-null object
# PW_SOURCE_YEAR                 6994 non-null float64
# PW_SOURCE_OTHER                6632 non-null object
# WAGE_RATE_OF_PAY_FROM          7001 non-null float64
# WAGE_RATE_OF_PAY_TO            7000 non-null float64
# WAGE_UNIT_OF_PAY               6999 non-null object
# H1B_DEPENDENT                  6746 non-null object
# WILLFUL_VIOLATOR               6746 non-null object
# SUPPORT_H1B                    961 non-null object
# LABOR_CON_AGREE                2528 non-null object
# PUBLIC_DISCLOSURE_LOCATION     0 non-null float64
# WORKSITE_CITY                  6999 non-null object
# WORKSITE_COUNTY                6977 non-null object
# WORKSITE_STATE                 6999 non-null object
# WORKSITE_POSTAL_CODE           6997 non-null object
# ORIGINAL_CERT_DATE             637 non-null datetime64[ns]
# dtypes: datetime64[ns](5), float64(6), int64(9), object(32)
# memory usage: 2.8+ MB

# %%
data_eda['DURATION'] = data_eda['DECISION_DATE'] - data_eda['CASE_SUBMITTED']

# %%
data_eda.head(20)
# Out:
#            CASE_NUMBER CASE_STATUS CASE_SUBMITTED DECISION_DATE   VISA_CLASS  \
# 0   I-200-18026-338377   CERTIFIED     2018-01-29    2018-02-02         H-1B
# 1   I-200-17296-353451   CERTIFIED     2017-10-23    2017-10-27         H-1B
# 2   I-200-18242-524477   CERTIFIED     2018-08-30    2018-09-06         H-1B
# 3   I-200-18243-850522   CERTIFIED     2018-08-31    2018-09-07         H-1B
# 4   I-200-18142-939501   CERTIFIED     2018-05-22    2018-05-29         H-1B
# 5   I-200-18121-552858   CERTIFIED     2018-05-01    2018-05-07         H-1B
# 6   I-200-18215-849606   CERTIFIED     2018-08-03    2018-08-09         H-1B
# 7   I-201-17339-472823   CERTIFIED     2017-12-08    2017-12-14  H-1B1 Chile
# 8   I-200-18233-239931   CERTIFIED     2018-08-21    2018-08-27         H-1B
# 9   I-200-18059-006093   CERTIFIED     2018-02-28    2018-03-06         H-1B
# 10  I-200-18107-783286   CERTIFIED     2018-04-18    2018-04-24         H-1B
# 11  I-200-18095-871087   CERTIFIED     2018-04-05    2018-04-11         H-1B
# 12  I-200-18057-019597   CERTIFIED     2018-02-26    2018-03-02         H-1B
# 13  I-200-18065-583678   CERTIFIED     2018-03-06    2018-03-12         H-1B
# 14  I-200-18024-890131   CERTIFIED     2018-01-24    2018-01-30         H-1B
# 15  I-200-18060-517421   CERTIFIED     2018-03-02    2018-03-08         H-1B
# 16  I-200-18025-163902   CERTIFIED     2018-03-05    2018-03-09         H-1B
# 17  I-200-18058-501771   CERTIFIED     2018-03-05    2018-03-09         H-1B
# 18  I-200-18062-732579      DENIED     2018-03-05    2018-03-07         H-1B
# 19  I-200-18064-452947   CERTIFIED     2018-03-05    2018-03-09         H-1B
#
#    EMPLOYMENT_START_DATE EMPLOYMENT_END_DATE  \
# 0             2018-07-28          2021-07-27
# 1             2017-11-06          2020-11-06
# 2             2018-09-10          2021-09-09
# 3             2018-09-07          2021-09-06
# 4             2018-05-29          2021-05-28
# 5             2018-05-02          2018-10-26
# 6             2018-08-11          2021-08-11
# 7             2017-12-08          2019-06-07
# 8             2018-09-05          2021-09-04
# 9             2018-05-15          2021-05-15
# 10            2018-06-01          2021-05-31
# 11            2018-04-12          2021-04-11
# 12            2018-08-23          2021-08-22
# 13            2018-09-05          2021-09-04
# 14            2018-07-26          2021-07-25
# 15            2018-08-28          2021-08-27
# 16            2018-09-01          2021-08-30
# 17            2018-09-01          2021-08-31
# 18            2018-09-04          2021-09-03
# 19            2018-09-01          2021-09-01
#
#                              EMPLOYER_NAME EMPLOYER_BUSINESS_DBA  \
# 0                    MICROSOFT CORPORATION                   NaN
# 1                   ERNST & YOUNG U.S. LLP                   NaN
# 2                             LOGIXHUB LLC                   NaN
# 3                         ECLOUD LABS,INC.                   NaN
# 4                                OBERON IT                   NaN
# 5                            ICONSOFT INC.                   NaN
# 6   COGNIZANT TECHNOLOGY SOLUTIONS US CORP                   NaN
# 7                         ISHI SYSTEMS INC                   NaN
# 8                        WB SOLUTIONS, LLC                   NaN
# 9                  INFOSTRETCH CORPORATION                   NaN
# 10                    THE ESAB GROUP, INC.                   NaN
# 11        LARSEN & TOUBRO INFOTECH LIMITED                   NaN
# 12       TATA CONSULTANCY SERVICES LIMITED                   NaN
# 13                ACRO SERVICE CORPORATION                   NaN
# 14           TECH MAHINDRA (AMERICAS),INC.                   NaN
# 15               VERIZON DATA SERVICES LLC                   NaN
# 16                   SUNRISE BOULEVARD LLC                   NaN
# 17                             MODNE, INC.                   NaN
# 18           CORBINS SERVICE ELECTRIC, LLC                   NaN
# 19         THERAVANCE BIOPHARMA U.S., INC.  THERAVANCE BIOPHARMA
#
#                             EMPLOYER_ADDRESS   ...    WILLFUL_VIOLATOR  \
# 0                            1 MICROSOFT WAY   ...                   N
# 1                            200 PLAZA DRIVE   ...                   N
# 2                           320 DECKER DRIVE   ...                   N
# 3                          120 S WOOD AVENUE   ...                   N
# 4                      1404 W WALNUT HILL LN   ...                   N
# 5             101 CAMBRIDGE STREET SUITE 360   ...                   N
# 6                         211 QUALITY CIRCLE   ...                   N
# 7                          185 HUDSON STREET   ...                 NaN
# 8                        7320 E FLETCHER AVE   ...                   N
# 9        3200 PATRICK HENRY DRIVE, SUITE 250   ...                   N
# 10                       181 E. EVANS STREET   ...                   N
# 11  2035 LINCOLN HIGHWAY, EDISON SQUARE WEST   ...                   N
# 12                  9201 CORPORATE BOULEVARD   ...                   N
# 13                    39209 W. SIX MILE ROAD   ...                   N
# 14                        1001 DURHAM AVENUE   ...                   N
# 15                          600 HIDDEN RIDGE   ...                   N
# 16                           128 LINCOLN ST.   ...                   N
# 17              13915 CERRITOS CORPORATE DR.   ...                   N
# 18                       4829 S. 38TH STREET   ...                   N
# 19                          901 GATEWAY BLVD   ...                   N
#
#    SUPPORT_H1B LABOR_CON_AGREE PUBLIC_DISCLOSURE_LOCATION  \
# 0          NaN             NaN                        NaN
# 1          NaN             NaN                        NaN
# 2          NaN             NaN                        NaN
# 3            Y               Y                        NaN
# 4            Y             NaN                        NaN
# 5            Y             NaN                        NaN
# 6            Y             NaN                        NaN
# 7          NaN             NaN                        NaN
# 8            Y               Y                        NaN
# 9            Y               Y                        NaN
# 10         NaN             NaN                        NaN
# 11           Y             NaN                        NaN
# 12           Y             NaN                        NaN
# 13         NaN               Y                        NaN
# 14           Y               Y                        NaN
# 15         NaN             NaN                        NaN
# 16         NaN             NaN                        NaN
# 17         NaN             NaN                        NaN
# 18         NaN               Y                        NaN
# 19         NaN             NaN                        NaN
#
#           WORKSITE_CITY  WORKSITE_COUNTY  WORKSITE_STATE WORKSITE_POSTAL_CODE  \
# 0               REDMOND             KING              WA                98052
# 1           SANTA CLARA         SAN JOSE              CA                95110
# 2                IRVING           DALLAS              TX                75062
# 3            BIRMINGHAM           SHELBY              AL                35244
# 4               SUNRISE          BROWARD              FL                33323
# 5          JACKSONVILLE     DUVAL COUNTY              FL                32202
# 6          OWINGS MILLS        BALTIMORE              MD                21117
# 7           JERSEY CITY           HUDSON              NJ                07311
# 8            ALPHARETTA           FULTON              GA                30005
# 9            PLEASANTON          ALAMEDA              CA                94588
# 10              HANOVER             YORK              PA                17331
# 11     LONG ISLAND CITY           QUEENS              NY                11101
# 12             ST. PAUL           RAMSEY              MN                55112
# 13          ALBUQUERQUE       BERNALILLO              NM                87108
# 14           SOUTHFIELD          OAKLAND              MI                48034
# 15               IRVING           DALLAS              TX                75038
# 16               BOSTON          SUFFOLK              MA                02111
# 17             CERRITOS      LOS ANGELES              CA                90703
# 18              PHOENIX         MARICOPA              AZ                85040
# 19  SOUTH SAN FRANCISCO        SAN MATEO              CA                94080
#
#    ORIGINAL_CERT_DATE DURATION
# 0                 NaT   4 days
# 1                 NaT   4 days
# 2                 NaT   7 days
# 3                 NaT   7 days
# 4                 NaT   7 days
# 5                 NaT   6 days
# 6                 NaT   6 days
# 7                 NaT   6 days
# 8                 NaT   6 days
# 9                 NaT   6 days
# 10                NaT   6 days
# 11                NaT   6 days
# 12                NaT   4 days
# 13                NaT   6 days
# 14                NaT   6 days
# 15                NaT   6 days
# 16                NaT   4 days
# 17                NaT   4 days
# 18                NaT   2 days
# 19                NaT   4 days
#
# [20 rows x 53 columns]

# %%
eda_h = data_eda[['DURATION','CASE_STATUS','EMPLOYER_NAME', 'JOB_TITLE', 'SOC_CODE']]
eda_h.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7001 entries, 0 to 7000
# Data columns (total 5 columns):
# DURATION         7001 non-null timedelta64[ns]
# CASE_STATUS      7001 non-null object
# EMPLOYER_NAME    7001 non-null object
# JOB_TITLE        7001 non-null object
# SOC_CODE         6999 non-null object
# dtypes: object(4), timedelta64[ns](1)
# memory usage: 273.6+ KB

# %%
eda_h.describe()
# Out:
#                        DURATION
# count                      7001
# mean    42 days 15:31:32.815312
# std    157 days 01:49:58.645732
# min             0 days 00:00:00
# 25%             5 days 00:00:00
# 50%             6 days 00:00:00
# 75%             6 days 00:00:00
# max          1963 days 00:00:00

# %%
eda_h = eda_h.fillna({"SOC_CODE": 0})
eda_h.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7001 entries, 0 to 7000
# Data columns (total 5 columns):
# DURATION         7001 non-null timedelta64[ns]
# CASE_STATUS      7001 non-null object
# EMPLOYER_NAME    7001 non-null object
# JOB_TITLE        7001 non-null object
# SOC_CODE         7001 non-null object
# dtypes: object(4), timedelta64[ns](1)
# memory usage: 273.6+ KB

# %%
eda_h['CASE_STATUS'] = eda_h['CASE_STATUS'].astype('category')
eda_h['EMPLOYER_NAME'] = eda_h['EMPLOYER_NAME'].astype('category')
eda_h['JOB_TITLE'] = eda_h['JOB_TITLE'].astype('category')
eda_h['SOC_CODE'] = eda_h['SOC_CODE'].astype('category')

# %%
# Converting Duration to a float data type. 
eda_h['DURATION'] = eda_h['DURATION']/ np.timedelta64(1, 'h')

# %%
eda_h.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7001 entries, 0 to 7000
# Data columns (total 5 columns):
# DURATION         7001 non-null float64
# CASE_STATUS      7001 non-null category
# EMPLOYER_NAME    7001 non-null category
# JOB_TITLE        7001 non-null category
# SOC_CODE         7001 non-null category
# dtypes: category(4), float64(1)
# memory usage: 403.2 KB

# %%
#Current unit of Duration is hours 
eda_h.DURATION
# Out:
# 0        96.0
# 1        96.0
# 2       168.0
# 3       168.0
# 4       168.0
# 5       144.0
# 6       144.0
# 7       144.0
# 8       144.0
# 9       144.0
# 10      144.0
# 11      144.0
# 12       96.0
# 13      144.0
# 14      144.0
# 15      144.0
# 16       96.0
# 17       96.0
# 18       48.0
# 19       96.0
# 20      144.0
# 21      120.0
# 22      144.0
# 23      144.0
# 24       96.0
# 25       24.0
# 26      120.0
# 27      144.0
# 28      144.0
# 29      120.0
#         ...
# 6971    144.0
# 6972    168.0
# 6973    168.0
# 6974    144.0
# 6975    144.0
# 6976    144.0
# 6977    144.0
# 6978    144.0
# 6979    168.0
# 6980    144.0
# 6981    144.0
# 6982     96.0
# 6983    144.0
# 6984    168.0
# 6985    168.0
# 6986    144.0
# 6987     96.0
# 6988    144.0
# 6989    144.0
# 6990    168.0
# 6991     48.0
# 6992     96.0
# 6993     96.0
# 6994     96.0
# 6995     96.0
# 6996     48.0
# 6997    168.0
# 6998    168.0
# 6999    144.0
# 7000    168.0
# Name: DURATION, Length: 7001, dtype: float64

# %% [markdown]
# ### Statistical Inference Analysis on variable: Duration

# %%
# ECDF Function

def ecdf(data):
    """Compute ECDF for a one-dimensional array of measurements."""

    # Number of data points: n
    n = len(data)

    # x: sort the data
    x = np.sort(data)

    # y: range for y-axis
    y = np.arange(1, n+1) / n

    return x, y

# %%
# Plot a histogram 
duration = (eda_h.DURATION)/24  # To convert the hours to days

# plot hist
_ = plt.hist(duration, bins=10)

# labels
_ = plt.text(95.5, 0.5, r'$\mu= {},\ \sigma={}$'.format(round(np.mean(duration), 2), round(np.std(duration), 2)))
_ = plt.xlabel('Processing Time(Days)')
_ = plt.ylabel('Frequency')
_ = plt.title('Processing Time of Cases')

margins = 0.02
plt.xlim(0, 1750)
plt.show();

# %%
sns.set(rc={"figure.figsize": (12, 8)})
plt.style.use('fivethirtyeight')

# Plot the CDFs
x, y = ecdf(duration)

# draw 10k random samples from a normal distribution
nm_duration = np.random.normal(np.mean(duration), np.std(duration), 10000)
nm_x, nm_y = ecdf(nm_duration)

_ = plt.plot(x, y, marker='.', linestyle='none', color = 'red')
_ = plt.plot(nm_x, nm_y, color = 'orange')

_ = plt.xlabel('Processing Times (Days)')
_ = plt.ylabel('CDF')
_ = plt.title('Cumulative Distribution Function - Processing TImes of Cases')
margins = 0.02

plt.show();

# %% [markdown]
# From using the cumulative distribution function (CDF), I can conclude that observations belonging to the Duration variable (processing times) tend to a Normal Distribution.
#
# Using the Central Limit Theorem as my reference, the sample selected was RSS. trepresents less than 10% of the my population data and sample size is more than 30.

# %% [markdown]
# ### Is it possible that the processing time can be less than Average of 42.65 days?
# #### Ho: μ <= 42.65 days and Ha: μ >= 42.5 days

# %%
## Use Z-statistics with 1 tail at Z value of 1.96 (alpha =0.5)
pro_mean = np.mean(duration)
pro_s1 = np.std(duration)/np.sqrt(7001)

#From reviewing the available processing times at USCIS site ranges, selected a population mean of 40 days  
z_pro =(42.65 - 40)/pro_s1  
print('Z score:{:.05}'.format(z_pro))
# Out:
# Z score:1.4117

# %% [markdown]
# #### Analysis
# The result from the Z test indicates that I do not rejet the Null Hypothesis with a confidence of 95%. It opens the door to potential improvements on the processing time.

# %% [markdown]
# ### Analysis on Categorical variables

# %%
# Assign a classification (categories) to the Case Status and Soc Code
eda_h["C_cat"] = eda_h["CASE_STATUS"].cat.codes
eda_h["S_cat"] = eda_h["SOC_CODE"].cat.codes
eda_h.head()
# Out:
#    DURATION CASE_STATUS           EMPLOYER_NAME  \
# 0      96.0   CERTIFIED   MICROSOFT CORPORATION
# 1      96.0   CERTIFIED  ERNST & YOUNG U.S. LLP
# 2     168.0   CERTIFIED            LOGIXHUB LLC
# 3     168.0   CERTIFIED        ECLOUD LABS,INC.
# 4     168.0   CERTIFIED               OBERON IT
#
#                                       JOB_TITLE SOC_CODE  C_cat  S_cat
# 0                             SOFTWARE ENGINEER  15-1132      0     55
# 1                                    TAX SENIOR  13-2011      0     39
# 2                        DATABASE ADMINISTRATOR  15-1141      0     58
# 3  MICROSOFT DYNAMICS CRM APPLICATION DEVELOPER  15-1132      0     55
# 4                       SENIOR SYSTEM ARCHITECT  15-1132      0     55

# %%
sns.boxplot(x = 'C_cat', y = 'DURATION', data=eda_h)

sns.set(rc={"figure.figsize": (12, 8)})
plt.style.use('fivethirtyeight')

_ = plt.xlabel('Case Status')
_ = plt.ylabel('Processing Times (hours)')
_ = plt.title('Processing times (h) by Case Status')
plt.show()

# %%
# Counting how many times the SOC code was in the sample
codes= eda_h["S_cat"].value_counts()
topcodes = codes.head(10)
print(topcodes)
# Out:
# 55     2202
# 52      487
# 62      377
# 211     367
# 56      328
# 8       197
# 78      174
# 39      151
# 42      141
# 4       102
# Name: S_cat, dtype: int64

# %%
eda_h['CASE_STATUS'].value_counts()
# Out:
# CERTIFIED              5330
# DENIED                  908
# CERTIFIED-WITHDRAWN     637
# WITHDRAWN               126
# Name: CASE_STATUS, dtype: int64

# %%
#Histogram of the Top 5 Job Titles in H1B Visa application
top_codes = {'WEB APPL/ENGINEER DEVELOPER ': 2202, 'IT VP': 487, 'APAP DEVELOPER':377,  'PHYSICIANS': 367, 
        'WEB UI DEV': 328}
nam_e = list(top_codes.keys())
val_e = list(top_codes.values())

fig, ax = plt.subplots()
ax.bar(nam_e, val_e)
fig.suptitle('Histogram: Top 5 Job Titles')
# Out:
# Text(0.5,0.98,'Histogram: Top 5 Job Titles')

# %%
# Plot the Processing times for all Job C
sns.boxplot(x = 'S_cat', y = 'DURATION', data= eda_h)

sns.set(rc={"figure.figsize": (12, 8)})
plt.style.use('fivethirtyeight')

_ = plt.xlabel('Job Titles based on SOC codes')
_ = plt.ylabel('Processing Times (hours)')
_ = plt.title('Processing times (h) per Job Tittles')
plt.show()

# %%
#Plot Job tittles using SOC codes to find out the Status 
_ = sns.swarmplot(x = 'S_cat', y ='C_cat', data = eda_h)
_ = plt.xlabel('Job categories')
_ = plt.ylabel('Case Categories')

margins = 0.02
plt.show()

# %%
corr_df = pd.read_excel("/Users/sheikita/Desktop/data/Correlation.xlsx")
corr_df.head(20)
# Out:
#     SOC CODE  CASE_NUMBER  SUM DURATION (Hours)
# 0         55         2202                101740
# 1         52          487                 21617
# 2        211          367                 14391
# 3         54           99                 12927
# 4         96           67                 11482
# 5         62          377                 11198
# 6         56          328                  7570
# 7         78          174                  5236
# 8          8          197                  5013
# 9        101           36                  4453
# 10        42          141                  4366
# 11       229           30                  3899
# 12        99           17                  3170
# 13       148            2                  2900
# 14        33           91                  2778
# 15        39          151                  2730
# 16        66           35                  2713
# 17       216           20                  2660
# 18        67           49                  2648
# 19        58           46                  2603

# %%
corr_df = corr_df.rename(columns = {'CASE_NUMBER':'SOC_counts'})

# %%
corr_df = corr_df.rename(columns = {'SUM DURATION (Hours)':'Duration SUM'})

# %%
corr_df.reset_index()
# Out:
#      index  SOC CODE  SOC_counts  Duration SUM
# 0        0        55        2202        101740
# 1        1        52         487         21617
# 2        2       211         367         14391
# 3        3        54          99         12927
# 4        4        96          67         11482
# 5        5        62         377         11198
# 6        6        56         328          7570
# 7        7        78         174          5236
# 8        8         8         197          5013
# 9        9       101          36          4453
# 10      10        42         141          4366
# 11      11       229          30          3899
# 12      12        99          17          3170
# 13      13       148           2          2900
# 14      14        33          91          2778
# 15      15        39         151          2730
# 16      16        66          35          2713
# 17      17       216          20          2660
# 18      18        67          49          2648
# 19      19        58          46          2603
# 20      20        73          53          2522
# 21      21        85          86          2519
# 22      22        95           7          2462
# 23      23       133          18          2461
# 24      24         4         102          2385
# 25      25        37          48          2284
# 26      26        77         102          2050
# 27      27       103          20          1923
# 28      28       136          16          1905
# 29      29        45           4          1889
# ..     ...       ...         ...           ...
# 230    230       256           1             3
# 231    231        70           1             3
# 232    232       139           1             2
# 233    233       165           1             2
# 234    234       167           1             2
# 235    235       176           1             2
# 236    236       219           1             2
# 237    237       226           1             2
# 238    238       235           1             2
# 239    239       238           1             2
# 240    240       244           1             2
# 241    241       246           1             2
# 242    242       251           1             2
# 243    243       254           1             2
# 244    244       259           1             2
# 245    245        27           1             2
# 246    246        35           1             2
# 247    247       118           1             1
# 248    248       126           1             1
# 249    249       169           1             1
# 250    250       188           1             1
# 251    251       200           1             1
# 252    252       223           1             1
# 253    253       224           1             1
# 254    254       230           1             1
# 255    255       232           1             1
# 256    256       237           1             1
# 257    257       241           1             1
# 258    258       250           1             1
# 259    259        26           1             1
#
# [260 rows x 4 columns]

# %% [markdown]
# #### Analysis
# The above calculation indicates that job category (55) equal to Software Developers, Applications (based on SOC code) is the job that most employers are trying to fill. Thus, takes has the longest processing time.

# %%
ax1 = corr_df.plot.scatter(x='SOC_counts', y = 'Duration SUM', c='SOC CODE', colormap='viridis')

# %%
corr = corr_df.corr(method='pearson')
print(corr)
# Out:
#               SOC CODE  SOC_counts  Duration SUM
# SOC CODE      1.000000   -0.098238     -0.084718
# SOC_counts   -0.098238    1.000000      0.982424
# Duration SUM -0.084718    0.982424      1.000000

# %%
sns.heatmap(corr, vmin=0, vmax=1, linecolor = 'grey', linewidths = .5, cmap="YlGnBu", xticklabels=corr.columns.values, yticklabels=corr.columns.values)
plt.show()

# %% [markdown]
# The resulting correlation on the variables:  count job titles and how long it takes to process them is positive and very close to 1. Thus,  both variables have a stronger linear relationship.

# %%
corr = corr_df.corr(method='spearman')
print(corr)
# Out:
#               SOC CODE  SOC_counts  Duration SUM
# SOC CODE      1.000000   -0.404217     -0.390191
# SOC_counts   -0.404217    1.000000      0.840691
# Duration SUM -0.390191    0.840691      1.000000
