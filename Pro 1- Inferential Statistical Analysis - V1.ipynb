# %% [markdown]
# #  ML model that will predict likelihood of getting H1B approved
#
# ### Goal of the Project
#
# The goal of my project is to answer the following question: Is it possible to predict if an H1B application will be Certified or not given the selected company sponsor/job title/duration?
#
#
# ### Variables
#
# The project will focus on Company sponsor (Employers), Job Title, process Duration, salaries to start of. Note that to calculate the Duration, Decision Date and Case submitted date are used.
#
# ### Sample Date
#
# From the original data (650K observations), a random sample of 7K observations was drawn for the purpose of performing the analysis

# %%
# %matplotlib inline

import pandas as pd
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import seaborn as sns
import pylab
import bokeh.plotting as bkp
from mpl_toolkits.axes_grid1 import make_axes_locatable

# %%
data_eda = pd.read_excel("/Users/sheikita/Desktop/data/H-1B_EDAco.xlsx")

# %%
data_eda.head(20)
# Out:
#            CASE_NUMBER CASE_STATUS CASE_SUBMITTED DECISION_DATE   VISA_CLASS  \
# 0   I-200-18026-338377   CERTIFIED     2018-01-29    2018-02-02         H-1B
# 1   I-200-17296-353451   CERTIFIED     2017-10-23    2017-10-27         H-1B
# 2   I-200-18242-524477   CERTIFIED     2018-08-30    2018-09-06         H-1B
# 3   I-200-18243-850522   CERTIFIED     2018-08-31    2018-09-07         H-1B
# 4   I-200-18142-939501   CERTIFIED     2018-05-22    2018-05-29         H-1B
# 5   I-200-18121-552858   CERTIFIED     2018-05-01    2018-05-07         H-1B
# 6   I-200-18215-849606   CERTIFIED     2018-08-03    2018-08-09         H-1B
# 7   I-201-17339-472823   CERTIFIED     2017-12-08    2017-12-14  H-1B1 Chile
# 8   I-200-18233-239931   CERTIFIED     2018-08-21    2018-08-27         H-1B
# 9   I-200-18059-006093   CERTIFIED     2018-02-28    2018-03-06         H-1B
# 10  I-200-18107-783286   CERTIFIED     2018-04-18    2018-04-24         H-1B
# 11  I-200-18095-871087   CERTIFIED     2018-04-05    2018-04-11         H-1B
# 12  I-200-18057-019597   CERTIFIED     2018-02-26    2018-03-02         H-1B
# 13  I-200-18065-583678   CERTIFIED     2018-03-06    2018-03-12         H-1B
# 14  I-200-18024-890131   CERTIFIED     2018-01-24    2018-01-30         H-1B
# 15  I-200-18060-517421   CERTIFIED     2018-03-02    2018-03-08         H-1B
# 16  I-200-18025-163902   CERTIFIED     2018-03-05    2018-03-09         H-1B
# 17  I-200-18058-501771   CERTIFIED     2018-03-05    2018-03-09         H-1B
# 18  I-200-18062-732579      DENIED     2018-03-05    2018-03-07         H-1B
# 19  I-200-18064-452947   CERTIFIED     2018-03-05    2018-03-09         H-1B
#
#    EMPLOYMENT_START_DATE EMPLOYMENT_END_DATE  \
# 0             2018-07-28          2021-07-27
# 1             2017-11-06          2020-11-06
# 2             2018-09-10          2021-09-09
# 3             2018-09-07          2021-09-06
# 4             2018-05-29          2021-05-28
# 5             2018-05-02          2018-10-26
# 6             2018-08-11          2021-08-11
# 7             2017-12-08          2019-06-07
# 8             2018-09-05          2021-09-04
# 9             2018-05-15          2021-05-15
# 10            2018-06-01          2021-05-31
# 11            2018-04-12          2021-04-11
# 12            2018-08-23          2021-08-22
# 13            2018-09-05          2021-09-04
# 14            2018-07-26          2021-07-25
# 15            2018-08-28          2021-08-27
# 16            2018-09-01          2021-08-30
# 17            2018-09-01          2021-08-31
# 18            2018-09-04          2021-09-03
# 19            2018-09-01          2021-09-01
#
#                              EMPLOYER_NAME EMPLOYER_BUSINESS_DBA  \
# 0                    MICROSOFT CORPORATION                   NaN
# 1                   ERNST & YOUNG U.S. LLP                   NaN
# 2                             LOGIXHUB LLC                   NaN
# 3                         ECLOUD LABS,INC.                   NaN
# 4                                OBERON IT                   NaN
# 5                            ICONSOFT INC.                   NaN
# 6   COGNIZANT TECHNOLOGY SOLUTIONS US CORP                   NaN
# 7                         ISHI SYSTEMS INC                   NaN
# 8                        WB SOLUTIONS, LLC                   NaN
# 9                  INFOSTRETCH CORPORATION                   NaN
# 10                    THE ESAB GROUP, INC.                   NaN
# 11        LARSEN & TOUBRO INFOTECH LIMITED                   NaN
# 12       TATA CONSULTANCY SERVICES LIMITED                   NaN
# 13                ACRO SERVICE CORPORATION                   NaN
# 14           TECH MAHINDRA (AMERICAS),INC.                   NaN
# 15               VERIZON DATA SERVICES LLC                   NaN
# 16                   SUNRISE BOULEVARD LLC                   NaN
# 17                             MODNE, INC.                   NaN
# 18           CORBINS SERVICE ELECTRIC, LLC                   NaN
# 19         THERAVANCE BIOPHARMA U.S., INC.  THERAVANCE BIOPHARMA
#
#                             EMPLOYER_ADDRESS        ...         H1B_DEPENDENT  \
# 0                            1 MICROSOFT WAY        ...                     N
# 1                            200 PLAZA DRIVE        ...                     N
# 2                           320 DECKER DRIVE        ...                     N
# 3                          120 S WOOD AVENUE        ...                     Y
# 4                      1404 W WALNUT HILL LN        ...                     Y
# 5             101 CAMBRIDGE STREET SUITE 360        ...                     Y
# 6                         211 QUALITY CIRCLE        ...                     Y
# 7                          185 HUDSON STREET        ...                   NaN
# 8                        7320 E FLETCHER AVE        ...                     Y
# 9        3200 PATRICK HENRY DRIVE, SUITE 250        ...                     Y
# 10                       181 E. EVANS STREET        ...                     N
# 11  2035 LINCOLN HIGHWAY, EDISON SQUARE WEST        ...                     Y
# 12                  9201 CORPORATE BOULEVARD        ...                     Y
# 13                    39209 W. SIX MILE ROAD        ...                     N
# 14                        1001 DURHAM AVENUE        ...                     Y
# 15                          600 HIDDEN RIDGE        ...                     N
# 16                           128 LINCOLN ST.        ...                     N
# 17              13915 CERRITOS CORPORATE DR.        ...                     N
# 18                       4829 S. 38TH STREET        ...                     N
# 19                          901 GATEWAY BLVD        ...                     N
#
#    WILLFUL_VIOLATOR SUPPORT_H1B LABOR_CON_AGREE PUBLIC_DISCLOSURE_LOCATION  \
# 0                 N         NaN             NaN                        NaN
# 1                 N         NaN             NaN                        NaN
# 2                 N         NaN             NaN                        NaN
# 3                 N           Y               Y                        NaN
# 4                 N           Y             NaN                        NaN
# 5                 N           Y             NaN                        NaN
# 6                 N           Y             NaN                        NaN
# 7               NaN         NaN             NaN                        NaN
# 8                 N           Y               Y                        NaN
# 9                 N           Y               Y                        NaN
# 10                N         NaN             NaN                        NaN
# 11                N           Y             NaN                        NaN
# 12                N           Y             NaN                        NaN
# 13                N         NaN               Y                        NaN
# 14                N           Y               Y                        NaN
# 15                N         NaN             NaN                        NaN
# 16                N         NaN             NaN                        NaN
# 17                N         NaN             NaN                        NaN
# 18                N         NaN               Y                        NaN
# 19                N         NaN             NaN                        NaN
#
#           WORKSITE_CITY  WORKSITE_COUNTY WORKSITE_STATE WORKSITE_POSTAL_CODE  \
# 0               REDMOND             KING             WA                98052
# 1           SANTA CLARA         SAN JOSE             CA                95110
# 2                IRVING           DALLAS             TX                75062
# 3            BIRMINGHAM           SHELBY             AL                35244
# 4               SUNRISE          BROWARD             FL                33323
# 5          JACKSONVILLE     DUVAL COUNTY             FL                32202
# 6          OWINGS MILLS        BALTIMORE             MD                21117
# 7           JERSEY CITY           HUDSON             NJ                07311
# 8            ALPHARETTA           FULTON             GA                30005
# 9            PLEASANTON          ALAMEDA             CA                94588
# 10              HANOVER             YORK             PA                17331
# 11     LONG ISLAND CITY           QUEENS             NY                11101
# 12             ST. PAUL           RAMSEY             MN                55112
# 13          ALBUQUERQUE       BERNALILLO             NM                87108
# 14           SOUTHFIELD          OAKLAND             MI                48034
# 15               IRVING           DALLAS             TX                75038
# 16               BOSTON          SUFFOLK             MA                02111
# 17             CERRITOS      LOS ANGELES             CA                90703
# 18              PHOENIX         MARICOPA             AZ                85040
# 19  SOUTH SAN FRANCISCO        SAN MATEO             CA                94080
#
#    ORIGINAL_CERT_DATE
# 0                 NaT
# 1                 NaT
# 2                 NaT
# 3                 NaT
# 4                 NaT
# 5                 NaT
# 6                 NaT
# 7                 NaT
# 8                 NaT
# 9                 NaT
# 10                NaT
# 11                NaT
# 12                NaT
# 13                NaT
# 14                NaT
# 15                NaT
# 16                NaT
# 17                NaT
# 18                NaT
# 19                NaT
#
# [20 rows x 52 columns]

# %%
data_eda.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7001 entries, 0 to 7000
# Data columns (total 52 columns):
# CASE_NUMBER                    7001 non-null object
# CASE_STATUS                    7001 non-null object
# CASE_SUBMITTED                 7001 non-null datetime64[ns]
# DECISION_DATE                  7001 non-null datetime64[ns]
# VISA_CLASS                     7001 non-null object
# EMPLOYMENT_START_DATE          7000 non-null datetime64[ns]
# EMPLOYMENT_END_DATE            7000 non-null datetime64[ns]
# EMPLOYER_NAME                  7001 non-null object
# EMPLOYER_BUSINESS_DBA          791 non-null object
# EMPLOYER_ADDRESS               7001 non-null object
# EMPLOYER_CITY                  7001 non-null object
# EMPLOYER_STATE                 7001 non-null object
# EMPLOYER_POSTAL_CODE           7001 non-null object
# EMPLOYER_COUNTRY               7001 non-null object
# EMPLOYER_PROVINCE              39 non-null object
# EMPLOYER_PHONE                 7001 non-null int64
# EMPLOYER_PHONE_EXT             354 non-null float64
# AGENT_REPRESENTING_EMPLOYER    6999 non-null object
# AGENT_ATTORNEY_NAME            7001 non-null object
# AGENT_ATTORNEY_CITY            5560 non-null object
# AGENT_ATTORNEY_STATE           5420 non-null object
# JOB_TITLE                      7001 non-null object
# SOC_CODE                       6999 non-null object
# SOC_NAME                       6999 non-null object
# NAICS_CODE                     7001 non-null int64
# TOTAL_WORKERS                  7001 non-null int64
# NEW_EMPLOYMENT                 7001 non-null int64
# CONTINUED_EMPLOYMENT           7001 non-null int64
# CHANGE_PREVIOUS_EMPLOYMENT     7001 non-null int64
# NEW_CONCURRENT_EMP             7001 non-null int64
# CHANGE_EMPLOYER                7001 non-null int64
# AMENDED_PETITION               7001 non-null int64
# FULL_TIME_POSITION             7001 non-null object
# PREVAILING_WAGE                7000 non-null float64
# PW_UNIT_OF_PAY                 6997 non-null object
# PW_WAGE_LEVEL                  3167 non-null object
# PW_SOURCE                      6998 non-null object
# PW_SOURCE_YEAR                 6994 non-null float64
# PW_SOURCE_OTHER                6632 non-null object
# WAGE_RATE_OF_PAY_FROM          7001 non-null float64
# WAGE_RATE_OF_PAY_TO            7000 non-null float64
# WAGE_UNIT_OF_PAY               6999 non-null object
# H1B_DEPENDENT                  6746 non-null object
# WILLFUL_VIOLATOR               6746 non-null object
# SUPPORT_H1B                    961 non-null object
# LABOR_CON_AGREE                2528 non-null object
# PUBLIC_DISCLOSURE_LOCATION     0 non-null float64
# WORKSITE_CITY                  6999 non-null object
# WORKSITE_COUNTY                6977 non-null object
# WORKSITE_STATE                 6999 non-null object
# WORKSITE_POSTAL_CODE           6997 non-null object
# ORIGINAL_CERT_DATE             637 non-null datetime64[ns]
# dtypes: datetime64[ns](5), float64(6), int64(9), object(32)
# memory usage: 2.8+ MB

# %%
data_eda['DURATION'] = data_eda['DECISION_DATE'] - data_eda['CASE_SUBMITTED']

# %%
data_eda.head(20)
# Out:
#            CASE_NUMBER CASE_STATUS CASE_SUBMITTED DECISION_DATE   VISA_CLASS  \
# 0   I-200-18026-338377   CERTIFIED     2018-01-29    2018-02-02         H-1B
# 1   I-200-17296-353451   CERTIFIED     2017-10-23    2017-10-27         H-1B
# 2   I-200-18242-524477   CERTIFIED     2018-08-30    2018-09-06         H-1B
# 3   I-200-18243-850522   CERTIFIED     2018-08-31    2018-09-07         H-1B
# 4   I-200-18142-939501   CERTIFIED     2018-05-22    2018-05-29         H-1B
# 5   I-200-18121-552858   CERTIFIED     2018-05-01    2018-05-07         H-1B
# 6   I-200-18215-849606   CERTIFIED     2018-08-03    2018-08-09         H-1B
# 7   I-201-17339-472823   CERTIFIED     2017-12-08    2017-12-14  H-1B1 Chile
# 8   I-200-18233-239931   CERTIFIED     2018-08-21    2018-08-27         H-1B
# 9   I-200-18059-006093   CERTIFIED     2018-02-28    2018-03-06         H-1B
# 10  I-200-18107-783286   CERTIFIED     2018-04-18    2018-04-24         H-1B
# 11  I-200-18095-871087   CERTIFIED     2018-04-05    2018-04-11         H-1B
# 12  I-200-18057-019597   CERTIFIED     2018-02-26    2018-03-02         H-1B
# 13  I-200-18065-583678   CERTIFIED     2018-03-06    2018-03-12         H-1B
# 14  I-200-18024-890131   CERTIFIED     2018-01-24    2018-01-30         H-1B
# 15  I-200-18060-517421   CERTIFIED     2018-03-02    2018-03-08         H-1B
# 16  I-200-18025-163902   CERTIFIED     2018-03-05    2018-03-09         H-1B
# 17  I-200-18058-501771   CERTIFIED     2018-03-05    2018-03-09         H-1B
# 18  I-200-18062-732579      DENIED     2018-03-05    2018-03-07         H-1B
# 19  I-200-18064-452947   CERTIFIED     2018-03-05    2018-03-09         H-1B
#
#    EMPLOYMENT_START_DATE EMPLOYMENT_END_DATE  \
# 0             2018-07-28          2021-07-27
# 1             2017-11-06          2020-11-06
# 2             2018-09-10          2021-09-09
# 3             2018-09-07          2021-09-06
# 4             2018-05-29          2021-05-28
# 5             2018-05-02          2018-10-26
# 6             2018-08-11          2021-08-11
# 7             2017-12-08          2019-06-07
# 8             2018-09-05          2021-09-04
# 9             2018-05-15          2021-05-15
# 10            2018-06-01          2021-05-31
# 11            2018-04-12          2021-04-11
# 12            2018-08-23          2021-08-22
# 13            2018-09-05          2021-09-04
# 14            2018-07-26          2021-07-25
# 15            2018-08-28          2021-08-27
# 16            2018-09-01          2021-08-30
# 17            2018-09-01          2021-08-31
# 18            2018-09-04          2021-09-03
# 19            2018-09-01          2021-09-01
#
#                              EMPLOYER_NAME EMPLOYER_BUSINESS_DBA  \
# 0                    MICROSOFT CORPORATION                   NaN
# 1                   ERNST & YOUNG U.S. LLP                   NaN
# 2                             LOGIXHUB LLC                   NaN
# 3                         ECLOUD LABS,INC.                   NaN
# 4                                OBERON IT                   NaN
# 5                            ICONSOFT INC.                   NaN
# 6   COGNIZANT TECHNOLOGY SOLUTIONS US CORP                   NaN
# 7                         ISHI SYSTEMS INC                   NaN
# 8                        WB SOLUTIONS, LLC                   NaN
# 9                  INFOSTRETCH CORPORATION                   NaN
# 10                    THE ESAB GROUP, INC.                   NaN
# 11        LARSEN & TOUBRO INFOTECH LIMITED                   NaN
# 12       TATA CONSULTANCY SERVICES LIMITED                   NaN
# 13                ACRO SERVICE CORPORATION                   NaN
# 14           TECH MAHINDRA (AMERICAS),INC.                   NaN
# 15               VERIZON DATA SERVICES LLC                   NaN
# 16                   SUNRISE BOULEVARD LLC                   NaN
# 17                             MODNE, INC.                   NaN
# 18           CORBINS SERVICE ELECTRIC, LLC                   NaN
# 19         THERAVANCE BIOPHARMA U.S., INC.  THERAVANCE BIOPHARMA
#
#                             EMPLOYER_ADDRESS   ...    WILLFUL_VIOLATOR  \
# 0                            1 MICROSOFT WAY   ...                   N
# 1                            200 PLAZA DRIVE   ...                   N
# 2                           320 DECKER DRIVE   ...                   N
# 3                          120 S WOOD AVENUE   ...                   N
# 4                      1404 W WALNUT HILL LN   ...                   N
# 5             101 CAMBRIDGE STREET SUITE 360   ...                   N
# 6                         211 QUALITY CIRCLE   ...                   N
# 7                          185 HUDSON STREET   ...                 NaN
# 8                        7320 E FLETCHER AVE   ...                   N
# 9        3200 PATRICK HENRY DRIVE, SUITE 250   ...                   N
# 10                       181 E. EVANS STREET   ...                   N
# 11  2035 LINCOLN HIGHWAY, EDISON SQUARE WEST   ...                   N
# 12                  9201 CORPORATE BOULEVARD   ...                   N
# 13                    39209 W. SIX MILE ROAD   ...                   N
# 14                        1001 DURHAM AVENUE   ...                   N
# 15                          600 HIDDEN RIDGE   ...                   N
# 16                           128 LINCOLN ST.   ...                   N
# 17              13915 CERRITOS CORPORATE DR.   ...                   N
# 18                       4829 S. 38TH STREET   ...                   N
# 19                          901 GATEWAY BLVD   ...                   N
#
#    SUPPORT_H1B LABOR_CON_AGREE PUBLIC_DISCLOSURE_LOCATION  \
# 0          NaN             NaN                        NaN
# 1          NaN             NaN                        NaN
# 2          NaN             NaN                        NaN
# 3            Y               Y                        NaN
# 4            Y             NaN                        NaN
# 5            Y             NaN                        NaN
# 6            Y             NaN                        NaN
# 7          NaN             NaN                        NaN
# 8            Y               Y                        NaN
# 9            Y               Y                        NaN
# 10         NaN             NaN                        NaN
# 11           Y             NaN                        NaN
# 12           Y             NaN                        NaN
# 13         NaN               Y                        NaN
# 14           Y               Y                        NaN
# 15         NaN             NaN                        NaN
# 16         NaN             NaN                        NaN
# 17         NaN             NaN                        NaN
# 18         NaN               Y                        NaN
# 19         NaN             NaN                        NaN
#
#           WORKSITE_CITY  WORKSITE_COUNTY  WORKSITE_STATE WORKSITE_POSTAL_CODE  \
# 0               REDMOND             KING              WA                98052
# 1           SANTA CLARA         SAN JOSE              CA                95110
# 2                IRVING           DALLAS              TX                75062
# 3            BIRMINGHAM           SHELBY              AL                35244
# 4               SUNRISE          BROWARD              FL                33323
# 5          JACKSONVILLE     DUVAL COUNTY              FL                32202
# 6          OWINGS MILLS        BALTIMORE              MD                21117
# 7           JERSEY CITY           HUDSON              NJ                07311
# 8            ALPHARETTA           FULTON              GA                30005
# 9            PLEASANTON          ALAMEDA              CA                94588
# 10              HANOVER             YORK              PA                17331
# 11     LONG ISLAND CITY           QUEENS              NY                11101
# 12             ST. PAUL           RAMSEY              MN                55112
# 13          ALBUQUERQUE       BERNALILLO              NM                87108
# 14           SOUTHFIELD          OAKLAND              MI                48034
# 15               IRVING           DALLAS              TX                75038
# 16               BOSTON          SUFFOLK              MA                02111
# 17             CERRITOS      LOS ANGELES              CA                90703
# 18              PHOENIX         MARICOPA              AZ                85040
# 19  SOUTH SAN FRANCISCO        SAN MATEO              CA                94080
#
#    ORIGINAL_CERT_DATE DURATION
# 0                 NaT   4 days
# 1                 NaT   4 days
# 2                 NaT   7 days
# 3                 NaT   7 days
# 4                 NaT   7 days
# 5                 NaT   6 days
# 6                 NaT   6 days
# 7                 NaT   6 days
# 8                 NaT   6 days
# 9                 NaT   6 days
# 10                NaT   6 days
# 11                NaT   6 days
# 12                NaT   4 days
# 13                NaT   6 days
# 14                NaT   6 days
# 15                NaT   6 days
# 16                NaT   4 days
# 17                NaT   4 days
# 18                NaT   2 days
# 19                NaT   4 days
#
# [20 rows x 53 columns]

# %%
eda_h = data_eda[['DURATION','CASE_STATUS','EMPLOYER_NAME', 'JOB_TITLE', 'TOTAL_WORKERS', 'SOC_CODE']]
eda_h.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7001 entries, 0 to 7000
# Data columns (total 6 columns):
# DURATION         7001 non-null timedelta64[ns]
# CASE_STATUS      7001 non-null object
# EMPLOYER_NAME    7001 non-null object
# JOB_TITLE        7001 non-null object
# TOTAL_WORKERS    7001 non-null int64
# SOC_CODE         6999 non-null object
# dtypes: int64(1), object(4), timedelta64[ns](1)
# memory usage: 328.2+ KB

# %%
eda_h.SOC_CODE.value_counts(dropna=False)
# Out:
# 15-1132       2202
# 15-1121        487
# 15-1199        377
# 29-1069        367
# 15-1133        328
# 11-3021        197
# 17-2072        174
# 13-2011        151
# 13-2051        141
# 17-2071        102
# 11-2021        102
# 15-1131         99
# 13-1111         91
# 17-2141         86
# 29-1063         75
# 11-3031         69
# 19-1021         67
# 23-1011         65
# 15-1142         64
# 15-2031         63
# 17-2051         53
# 17-1011         49
# 13-1161         48
# 15-1141         46
# 15-1122         43
# 11-1021         41
# 15-1111         38
# 11-9041         36
# 19-1042         36
# 15-2041         35
#               ...
# 19-3039          1
# 53-3021          1
# 29-2041          1
# 43-6012          1
# 19-4011          1
# 17-3022          1
# 29-1181          1
# 19-1029.02       1
# 15-1052          1
# 11-9031          1
# 13-2052          1
# 35-2014          1
# 25-1051          1
# 29-1022          1
# 13-1023          1
# 41-3011          1
# 19-4093          1
# 25-9021          1
# 13-1131          1
# 21-1091          1
# 25-2053          1
# 29-1031          1
# 25-1069          1
# 13-1011          1
# 35-2011          1
# 41-3098          1
# 25-1054          1
# 19-3032          1
# 19-3099          1
# 21-1099          1
# Name: SOC_CODE, Length: 260, dtype: int64

# %%
eda_h.describe()
# Out:
#                        DURATION  TOTAL_WORKERS
# count                      7001    7001.000000
# mean    42 days 15:31:32.815312       2.632767
# std    157 days 01:49:58.645732       7.982327
# min             0 days 00:00:00       0.000000
# 25%             5 days 00:00:00       1.000000
# 50%             6 days 00:00:00       1.000000
# 75%             6 days 00:00:00       1.000000
# max          1963 days 00:00:00     150.000000

# %%
eda_h = eda_h.fillna({"SOC_CODE": 0})
eda_h.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7001 entries, 0 to 7000
# Data columns (total 6 columns):
# DURATION         7001 non-null timedelta64[ns]
# CASE_STATUS      7001 non-null object
# EMPLOYER_NAME    7001 non-null object
# JOB_TITLE        7001 non-null object
# TOTAL_WORKERS    7001 non-null int64
# SOC_CODE         7001 non-null object
# dtypes: int64(1), object(4), timedelta64[ns](1)
# memory usage: 328.2+ KB

# %%
eda_h['CASE_STATUS'] = eda_h['CASE_STATUS'].astype('category')
eda_h['EMPLOYER_NAME'] = eda_h['EMPLOYER_NAME'].astype('category')
eda_h['JOB_TITLE'] = eda_h['JOB_TITLE'].astype('category')
eda_h['TOTAL_WORKERS'] = eda_h['TOTAL_WORKERS'].astype('category')
eda_h['SOC_CODE'] = eda_h['SOC_CODE'].astype('category')

# %%
eda_h['DURATION'] = eda_h['DURATION']/ np.timedelta64(1, 'h')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /anaconda3/lib/python3.6/site-packages/pandas/core/ops.py in na_op(x, y)
#     675         try:
# --> 676             result = expressions.evaluate(op, str_rep, x, y, **eval_kwargs)
#     677         except TypeError:
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/computation/expressions.py in evaluate(op, op_str, a, b, use_numexpr, **eval_kwargs)
#     203     if use_numexpr:
# --> 204         return _evaluate(op, op_str, a, b, **eval_kwargs)
#     205     return _evaluate_standard(op, op_str, a, b)
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/computation/expressions.py in _evaluate_numexpr(op, op_str, a, b, truediv, reversed, **eval_kwargs)
#     118     if result is None:
# --> 119         result = _evaluate_standard(op, op_str, a, b)
#     120
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/computation/expressions.py in _evaluate_standard(op, op_str, a, b, **eval_kwargs)
#      63     with np.errstate(all='ignore'):
# ---> 64         return op(a, b)
#      65
#
# TypeError: ufunc true_divide cannot use operands with types dtype('float64') and dtype('<m8[h]')
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-7b6418273497> in <module>()
# ----> 1 eda_h['DURATION'] = eda_h['DURATION']/ np.timedelta64(1, 'h')
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/ops.py in wrapper(left, right, name, na_op)
#     737                 lvalues = lvalues.values
#     738
# --> 739         result = wrap_results(safe_na_op(lvalues, rvalues))
#     740         return construct_result(
#     741             left,
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/ops.py in safe_na_op(lvalues, rvalues)
#     698         try:
#     699             with np.errstate(all='ignore'):
# --> 700                 return na_op(lvalues, rvalues)
#     701         except Exception:
#     702             if isinstance(rvalues, ABCSeries):
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/ops.py in na_op(x, y)
#     684                 result = np.empty(len(x), dtype=x.dtype)
#     685                 mask = notna(x)
# --> 686                 result[mask] = op(x[mask], y)
#     687             else:
#     688                 raise TypeError("{typ} cannot perform the operation "
#
# TypeError: ufunc true_divide cannot use operands with types dtype('float64') and dtype('<m8[h]')

# %%
eda_h.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7001 entries, 0 to 7000
# Data columns (total 6 columns):
# DURATION         7001 non-null float64
# CASE_STATUS      7001 non-null category
# EMPLOYER_NAME    7001 non-null category
# JOB_TITLE        7001 non-null category
# TOTAL_WORKERS    7001 non-null category
# SOC_CODE         7001 non-null category
# dtypes: category(5), float64(1)
# memory usage: 411.5 KB

# %%
eda_h.describe()
# Out:
#            DURATION
# count   7001.000000
# mean    1023.525782
# std     3769.832957
# min        0.000000
# 25%      120.000000
# 50%      144.000000
# 75%      144.000000
# max    47112.000000

# %%
eda_h.DURATION
# Out:
# 0        96.0
# 1        96.0
# 2       168.0
# 3       168.0
# 4       168.0
# 5       144.0
# 6       144.0
# 7       144.0
# 8       144.0
# 9       144.0
# 10      144.0
# 11      144.0
# 12       96.0
# 13      144.0
# 14      144.0
# 15      144.0
# 16       96.0
# 17       96.0
# 18       48.0
# 19       96.0
# 20      144.0
# 21      120.0
# 22      144.0
# 23      144.0
# 24       96.0
# 25       24.0
# 26      120.0
# 27      144.0
# 28      144.0
# 29      120.0
#         ...
# 6971    144.0
# 6972    168.0
# 6973    168.0
# 6974    144.0
# 6975    144.0
# 6976    144.0
# 6977    144.0
# 6978    144.0
# 6979    168.0
# 6980    144.0
# 6981    144.0
# 6982     96.0
# 6983    144.0
# 6984    168.0
# 6985    168.0
# 6986    144.0
# 6987     96.0
# 6988    144.0
# 6989    144.0
# 6990    168.0
# 6991     48.0
# 6992     96.0
# 6993     96.0
# 6994     96.0
# 6995     96.0
# 6996     48.0
# 6997    168.0
# 6998    168.0
# 6999    144.0
# 7000    168.0
# Name: DURATION, Length: 7001, dtype: float64

# %%
# ECDF Function

def ecdf(data):
    """Compute ECDF for a one-dimensional array of measurements."""

    # Number of data points: n
    n = len(data)

    # x: sort the data
    x = np.sort(data)

    # y: range for y-axis
    y = np.arange(1, n+1) / n

    return x, y

# %%
# Plot a histogram 
duration = (eda_h.DURATION)/24  # To convert the hours to days

# plot hist
_ = plt.hist(duration, bins=10)

# labels
_ = plt.text(95.5, 0.5, r'$\mu= {},\ \sigma={}$'.format(round(np.mean(duration), 2), round(np.std(duration), 2)))
_ = plt.xlabel('Processing Time(Days)')
_ = plt.ylabel('Frequency')
_ = plt.title('Processing Time of Cases')

margins = 0.02
plt.xlim(0, 1750)
plt.show();

# %%
sns.set(rc={"figure.figsize": (12, 8)})
plt.style.use('fivethirtyeight')

# Plot the CDFs
x, y = ecdf(duration)

# draw 10k random samples from a normal distribution
nm_duration = np.random.normal(np.mean(duration), np.std(duration), 10000)
nm_x, nm_y = ecdf(nm_duration)

_ = plt.plot(x, y, marker='.', linestyle='none', color = 'red')
_ = plt.plot(nm_x, nm_y, color = 'orange')

_ = plt.xlabel('Processing Times (Days)')
_ = plt.ylabel('CDF')
_ = plt.title('Cumulative Distribution Function - Processing TImes of Cases')
margins = 0.02

plt.show();

# %% [markdown]
# From my analysis, I can state that the processing time data tends to a Normal Distribution.
# Using the Central Limit Theorem as my reference, sample was RSS, represents less than 10% of the my population data
# and sample is more than 30.

# %% [markdown]
# ### Is it possible that the processing time can be less than Average of 42.65 days?
# #### Ho: μ <= 42.65 days and Ha: μ >= 42.5 days

# %%
## Use Z-statistics with 1 tail at Z value of 1.96
pro_mean = np.mean(duration)
pro_s1 = np.std(duration)/np.sqrt(7001)

z_pro =(42.65 - 40)/pro_s1   #From rprocessing times ranges available from  USCIS site, selected 40 days  
print('Z score:{:.05}'.format(z_pro))
# Out:
# Z score:1.4116

# %% [markdown]
# #### Analysis
# The result from the Z test indicates that I do not rejet the Null Hypothesis with a confidence of 95%. It opens the door to potential improvements on the processing time.

# %%
eda_h["C_cat"] = eda_h["CASE_STATUS"].cat.codes
eda_h["S_cat"] = eda_h["SOC_CODE"].cat.codes
eda_h.head()
# Out:
#    DURATION CASE_STATUS           EMPLOYER_NAME  \
# 0      96.0   CERTIFIED   MICROSOFT CORPORATION
# 1      96.0   CERTIFIED  ERNST & YOUNG U.S. LLP
# 2     168.0   CERTIFIED            LOGIXHUB LLC
# 3     168.0   CERTIFIED        ECLOUD LABS,INC.
# 4     168.0   CERTIFIED               OBERON IT
#
#                                       JOB_TITLE TOTAL_WORKERS SOC_CODE  C_cat  \
# 0                             SOFTWARE ENGINEER             1  15-1132      0
# 1                                    TAX SENIOR             1  13-2011      0
# 2                        DATABASE ADMINISTRATOR             1  15-1141      0
# 3  MICROSOFT DYNAMICS CRM APPLICATION DEVELOPER             1  15-1132      0
# 4                       SENIOR SYSTEM ARCHITECT             1  15-1132      0
#
#    S_cat
# 0     55
# 1     39
# 2     58
# 3     55
# 4     55

# %%
sns.boxplot(x = 'C_cat', y = 'DURATION', data=eda_h)

sns.set(rc={"figure.figsize": (12, 8)})
plt.style.use('fivethirtyeight')

_ = plt.xlabel('Case Status')
_ = plt.ylabel('Processing Times (hours)')
_ = plt.title('Processing times (h) by Case Status')
plt.show()

# %%
eda_h["Job_cat"] = eda_h["JOB_TITLE"].cat.codes

# %%
eda_h.sort_values('Job_cat', ascending = False)
# Out:
#       DURATION          CASE_STATUS  \
# 6336     168.0            CERTIFIED
# 5901     144.0            CERTIFIED
# 5314     144.0            CERTIFIED
# 3593     144.0            CERTIFIED
# 1422     144.0            CERTIFIED
# 2136     144.0            CERTIFIED
# 3162    3240.0  CERTIFIED-WITHDRAWN
# 2468      72.0               DENIED
# 6967     168.0            CERTIFIED
# 335      144.0            CERTIFIED
# 2621     144.0            CERTIFIED
# 1810     168.0            CERTIFIED
# 4483      96.0               DENIED
# 3506     144.0            CERTIFIED
# 881       72.0               DENIED
# 2552     144.0               DENIED
# 2190     144.0            CERTIFIED
# 512      144.0            CERTIFIED
# 2719      96.0            CERTIFIED
# 2714      96.0            CERTIFIED
# 1766     144.0            CERTIFIED
# 6937     168.0            CERTIFIED
# 6755     144.0            CERTIFIED
# 4464     144.0            CERTIFIED
# 357       96.0            CERTIFIED
# 4853      24.0               DENIED
# 3605      48.0               DENIED
# 4939     144.0            CERTIFIED
# 3494     144.0            CERTIFIED
# 4858      96.0            CERTIFIED
# ...        ...                  ...
# 4234     144.0            CERTIFIED
# 1307     144.0            CERTIFIED
# 518      144.0            CERTIFIED
# 2843     144.0               DENIED
# 549    22200.0  CERTIFIED-WITHDRAWN
# 2311     144.0            CERTIFIED
# 4706     144.0            CERTIFIED
# 3154      96.0            CERTIFIED
# 1296     144.0            CERTIFIED
# 912      144.0            CERTIFIED
# 3451      96.0            CERTIFIED
# 5243     168.0            CERTIFIED
# 2690     144.0            CERTIFIED
# 5394      48.0               DENIED
# 5044      48.0               DENIED
# 6768      96.0            CERTIFIED
# 3572      96.0            CERTIFIED
# 749      168.0            CERTIFIED
# 3716     144.0            CERTIFIED
# 1202      96.0               DENIED
# 1243     144.0            CERTIFIED
# 3842     168.0            CERTIFIED
# 1579     576.0  CERTIFIED-WITHDRAWN
# 3090      48.0               DENIED
# 4214     144.0            CERTIFIED
# 5241     144.0            CERTIFIED
# 649      168.0            CERTIFIED
# 1252     144.0            CERTIFIED
# 107       72.0               DENIED
# 4836      96.0            CERTIFIED
#
#                                           EMPLOYER_NAME  \
# 6336               LAW OFFICES OF MICHAEL I BROOKS, APC
# 5901                 SOUTHERN ILLINOIS MEDICAL SERVICES
# 5314                                         AKRIS INC.
# 3593                                      ACCENTURE LLP
# 1422                                  NCS PEARSON, INC.
# 2136                                       EQUIFAX INC.
# 3162                               TIBCO SOFTWARE, INC.
# 2468                                 STREET CORPORATION
# 6967                                 BEST BUY CO., INC.
# 335                              ARROW ELECTRONICS INC.
# 2621                          TRIANGLE DIRECT MEDIA LLC
# 1810                                     SYNOPSYS, INC.
# 4483  KNOX COUNTY ASSOCIATION FOR RETARDED CITIZENS,...
# 3506                                     AUDIOEYE, INC.
# 881                                          CSUSA INC.
# 2552                     COMPUNNEL SOFTWARE GROUP, INC.
# 2190                               BANK OF AMERICA N.A.
# 512                                BANK OF AMERICA N.A.
# 2719                               BANK OF AMERICA N.A.
# 2714                               BANK OF AMERICA N.A.
# 1766                       NOMURA AMERICA SERVICES, LLC
# 6937                               SYMANTEC CORPORATION
# 6755                               BANK OF AMERICA N.A.
# 4464                              FISERV SOLUTIONS, LLC
# 357                                        STAPLES, INC
# 4853               HEALTHCARE IMPROVEMENT SCIENCES, LLC
# 3605                                TIGER ANALYTICS LLC
# 4939                                        TESLA, INC.
# 3494                                SALESFORCE.COM INC.
# 4858                      PROSPERITY SERVICE GROUP, LLC
# ...                                                 ...
# 4234                                 JOE L TORRES, P.C.
# 1307                            CORE TECH INTERNATIONAL
# 518                          JAMES TSEMPELIS, CPA, PLLC
# 2843                 GARCIA ROOFING AND SHEET METAL INC
# 549                              MINNESOTA PUBLIC RADIO
# 2311                                 EARTH ELEMENTS LLC
# 4706                       NATIONAL MARKETING RESOURCES
# 3154                                          NMSI, INC
# 1296                                    HYOSUNG USA INC
# 912                          HOTTA LIESENBERG SAITO LLP
# 3451                  CLASSICO DESIGN AND MARKETING LLC
# 5243                       ESPN SALES & MARKETING, INC.
# 2690                                        CMGRP, INC.
# 5394                                   HELLO DESIGN LLC
# 5044                                 AESCIT CORPORATION
# 6768                     BOWLING GREEN STATE UNIVERSITY
# 3572                          MICHIGAN STATE UNIVERSITY
# 749                           UNIVERSITY OF CONNECTICUT
# 3716                                  POPULUS GROUP LLC
# 1202                                  POPULUS GROUP LLC
# 1243                           KRYPTO IT SOLUTIONS, INC
# 3842                                   NORTHWELL HEALTH
# 1579                                 HOLLINS UNIVERSITY
# 3090                          VANDAMME ASSOCIATES, INC.
# 4214                         USM BUSINESS SYSTEMS, INC.
# 5241                      THOMSON REUTERS (MARKETS) LLC
# 649                                   POPULUS GROUP LLC
# 1252                     ACE AMERICAN INSURANCE COMPANY
# 107                                          DIZER CORP
# 4836                                        VLINK.INC.,
#
#                                               JOB_TITLE TOTAL_WORKERS  \
# 6336                                             WRITER             1
# 5901                               WOUND CARE PHYSICIAN             1
# 5314                          WHOLESALE DIRECTOR, PUNTO             1
# 3593        WEST TECHNOLOGY PROGRAM LEAD SENIOR MANAGER             1
# 1422         WEBLOGIC APPLICATIONS SYSTEM ADMINISTRATOR             1
# 2136              WEB USER INTERFACE DEVELOPER - CAREER             1
# 3162                                   WEB UI ARCHITECT             1
# 2468                                      WEB SEVELOPER             1
# 6967                             WEB OPERATIONS ANALYST             1
# 335                                     WEB ENGINEER II             1
# 2621                                      WEB DEVELOPER             1
# 1810                                      WEB DEVELOPER            25
# 4483                                      WEB DEVELOPER             1
# 3506                         WEB APPLICATIONS DEVELOPER             1
# 881                                WEB APP DEVELOPER II             1
# 2552                             WEB & GRAPHIC DESIGNER             1
# 2190                     VP; GLBL FIN CRIMES COMPL SPEC             1
# 512                               VP; CNSLT - APPS PROG             1
# 2719                           VP; BA PROFESSIONAL MKTS             1
# 2714                           VP, PROGRAMMER PROF MKTS             1
# 1766     VP, IT (GLOBAL MARKETS INFORMATION TECHNOLOGY)             1
# 6937                           VP, INFORMATION SECURITY             1
# 6755                            VP, CNSLT - SYSTEMS ENG             1
# 4464                   VP, BUSINESS TRANSFORMATION, DIS             1
# 357                             VP RETAIL MERCHANDISING             1
# 4853                     VP OF TRAINING AND DEVELOPMENT             1
# 3605                                   VP OF CONSULTING             1
# 4939                                   VP NORTH AMERICA             1
# 3494                        VP IOT BUSINESS DEVELOPMENT             1
# 4858  VP - CORPORATE DEVELOPMENT, FINANCIAL PLANNING...             1
# ...                                                 ...           ...
# 4234                                         ACCOUNTANT             1
# 1307                                         ACCOUNTANT             1
# 518                                          ACCOUNTANT             1
# 2843                                         ACCOUNTANT             1
# 549                                          ACCOUNTANT             1
# 2311                                         ACCOUNTANT             1
# 4706                                         ACCOUNTANT             1
# 3154                                         ACCOUNTANT             1
# 1296                                         ACCOUNTANT             1
# 912                                          ACCOUNTANT             1
# 3451                                         ACCOUNTANT             1
# 5243                          ACCOUNT EXECUTIVE X GAMES             1
# 2690                                  ACCOUNT EXECUTIVE             1
# 5394                                   ACCOUNT DIRECTOR             1
# 5044                                   ACCOUNT DIRECTOR             1
# 6768                           ACCESSIBILITY SPECIALIST             1
# 3572                                ACADEMIC SPECIALIST             1
# 749                 ACADEMIC ASSISTANT 1 (STATISTICIAN)             1
# 3716                                     ABAP DEVELOPER             1
# 1202                                     ABAP DEVELOPER             1
# 1243                                AB INITIO DEVELOPER             1
# 3842                                            29-1069             1
# 1579          2018 FRANCES NIEDERER ARTIST IN RESIDENCE             1
# 3090                                            15-1132             1
# 4214                                         09/01/2018             1
# 5241                      .NET SENIOR SOFTWARE ENGINEER             1
# 649                                      .NET DEVELOPER             1
# 1252                                     .NET DEVELOPER             1
# 107                                      .NET DEVELOPER             1
# 4836                                     .NET ARCHITECT             1
#
#      SOC_CODE  C_cat  S_cat  Job_cat
# 6336  27-3043      0    192     3514
# 5901  29-1069      0    211     3513
# 5314  11-2022      0      5     3512
# 3593  11-3021      0      8     3511
# 1422  15-1142      0     59     3510
# 2136  15-1133      0     56     3509
# 3162  15-1132      1     55     3508
# 2468  15-1134      2     57     3507
# 6967  15-1132      0     55     3506
# 335   15-1132      0     55     3505
# 2621  15-1134      0     57     3504
# 1810  15-1134      0     57     3504
# 4483  15-1134      2     57     3504
# 3506  15-1132      0     55     3503
# 881   15-1134      2     57     3502
# 2552  27-1024      2    181     3501
# 2190  15-1122      0     53     3500
# 512   15-1132      0     55     3499
# 2719  15-1132      0     55     3498
# 2714  15-1132      0     55     3497
# 1766  15-1121      0     52     3496
# 6937  11-3021      0      8     3495
# 6755  15-1132      0     55     3494
# 4464  11-3021      0      8     3493
# 357   11-2022      0      5     3492
# 4853  25-9099      2    175     3491
# 3605  15-2031      2     65     3490
# 4939  11-2022      0      5     3489
# 3494  11-2022      0      5     3488
# 4858  11-3031      0      9     3487
# ...       ...    ...    ...      ...
# 4234  13-2011      0     39       15
# 1307  13-2011      0     39       15
# 518   13-2011      0     39       15
# 2843  13-2011      2     39       15
# 549   13-2011      1     39       15
# 2311  13-2011      0     39       15
# 4706  13-2011      0     39       15
# 3154  13-2011      0     39       15
# 1296  13-2011      0     39       15
# 912   13-2011      0     39       15
# 3451  13-2011      0     39       15
# 5243  41-3011      0    239       14
# 2690  27-3031      0    189       13
# 5394  13-1161      2     37       12
# 5044  11-1021      2      2       12
# 6768  21-1012      0    124       11
# 3572  25-1081      0    149       10
# 749   15-2041      0     66        9
# 3716  15-1132      0     55        8
# 1202  15-1199      2     62        8
# 1243  15-1132      0     55        7
# 3842  29-1069      0    211        6
# 1579  25-1121      1    152        5
# 3090  15-1132      2     55        4
# 4214  15-1132      0     55        3
# 5241  15-1132      0     55        2
# 649   15-1132      0     55        1
# 1252  15-1132      0     55        1
# 107   15-1132      2     55        1
# 4836  15-1132      0     55        0
#
# [7001 rows x 9 columns]

# %%
# Counting how many times the SOC code was in the sample
 codes= eda_h["S_cat"].value_counts()
topcodes = codes.head(10)
print(topcodes)
# Out:
# 55     2202
# 52      487
# 62      377
# 211     367
# 56      328
# 8       197
# 78      174
# 39      151
# 42      141
# 4       102
# Name: S_cat, dtype: int64

# %%
eda_h['CASE_STATUS'].value_counts()
# Out:
# CERTIFIED              5330
# DENIED                  908
# CERTIFIED-WITHDRAWN     637
# WITHDRAWN               126
# Name: CASE_STATUS, dtype: int64

# %%
#Histogram of the Top 5 Job Titles
top_codes = {'WEB APPL/ENGINEER DEVELOPER ': 2202, 'IT VP': 487, 'APAP DEVELOPER':377,  'PHYSICIANS': 367, 
        'WEB UI DEV': 328}
nam_e = list(top_codes.keys())
val_e = list(top_codes.values())

fig, ax = plt.subplots()
ax.bar(nam_e, val_e)
fig.suptitle('Top Job Titles Histogram')
# Out:
# Text(0.5,0.98,'Top Job Titles Histogram')

# %%
# Plot the Processing times for all Job C
sns.boxplot(x = 'S_cat', y = 'DURATION', data= eda_h)

sns.set(rc={"figure.figsize": (12, 8)})
plt.style.use('fivethirtyeight')

_ = plt.xlabel('Job Titles based on SOC codes')
_ = plt.ylabel('Processing Times (hours)')
_ = plt.title('Processing times (h) per Job Tittles')
plt.show()

# %%
#Plot Job tittles using SOC codes to find out the Status 
_ = sns.swarmplot(x = 'S_cat', y ='C_cat', data = eda_h)
_ = plt.xlabel('Job categories')
_ = plt.ylabel('Case Categories')

margins = 0.02
plt.show()

# %%
corr_df = pd.read_excel("/Users/sheikita/Desktop/data/Correlation.xlsx")
corr_df.head(20)
# Out:
#     SOC CODE  CASE_NUMBER  SUM DURATION (Hours)
# 0         55         2202                101740
# 1         52          487                 21617
# 2        211          367                 14391
# 3         54           99                 12927
# 4         96           67                 11482
# 5         62          377                 11198
# 6         56          328                  7570
# 7         78          174                  5236
# 8          8          197                  5013
# 9        101           36                  4453
# 10        42          141                  4366
# 11       229           30                  3899
# 12        99           17                  3170
# 13       148            2                  2900
# 14        33           91                  2778
# 15        39          151                  2730
# 16        66           35                  2713
# 17       216           20                  2660
# 18        67           49                  2648
# 19        58           46                  2603

# %%
corr_df = corr_df.rename(columns = {'CASE_NUMBER':'SOC_counts'})

# %%
corr_df = corr_df.rename(columns = {'SUM DURATION (Hours)':'Duration SUM'})

# %%
corr_df.reset_index()
# Out:
#      index  SOC CODE  SOC_counts  Duration SUM
# 0        0        55        2202        101740
# 1        1        52         487         21617
# 2        2       211         367         14391
# 3        3        54          99         12927
# 4        4        96          67         11482
# 5        5        62         377         11198
# 6        6        56         328          7570
# 7        7        78         174          5236
# 8        8         8         197          5013
# 9        9       101          36          4453
# 10      10        42         141          4366
# 11      11       229          30          3899
# 12      12        99          17          3170
# 13      13       148           2          2900
# 14      14        33          91          2778
# 15      15        39         151          2730
# 16      16        66          35          2713
# 17      17       216          20          2660
# 18      18        67          49          2648
# 19      19        58          46          2603
# 20      20        73          53          2522
# 21      21        85          86          2519
# 22      22        95           7          2462
# 23      23       133          18          2461
# 24      24         4         102          2385
# 25      25        37          48          2284
# 26      26        77         102          2050
# 27      27       103          20          1923
# 28      28       136          16          1905
# 29      29        45           4          1889
# ..     ...       ...         ...           ...
# 230    230       256           1             3
# 231    231        70           1             3
# 232    232       139           1             2
# 233    233       165           1             2
# 234    234       167           1             2
# 235    235       176           1             2
# 236    236       219           1             2
# 237    237       226           1             2
# 238    238       235           1             2
# 239    239       238           1             2
# 240    240       244           1             2
# 241    241       246           1             2
# 242    242       251           1             2
# 243    243       254           1             2
# 244    244       259           1             2
# 245    245        27           1             2
# 246    246        35           1             2
# 247    247       118           1             1
# 248    248       126           1             1
# 249    249       169           1             1
# 250    250       188           1             1
# 251    251       200           1             1
# 252    252       223           1             1
# 253    253       224           1             1
# 254    254       230           1             1
# 255    255       232           1             1
# 256    256       237           1             1
# 257    257       241           1             1
# 258    258       250           1             1
# 259    259        26           1             1
#
# [260 rows x 4 columns]

# %%
ax1 = corr_df.plot.scatter(x='SOC_counts', y = 'Duration SUM', c='SOC CODE', colormap='viridis')

# %%
corr = corr_df.corr(method='pearson')
print(corr)
# Out:
#               SOC CODE  SOC_counts  Duration SUM
# SOC CODE      1.000000   -0.098238     -0.084718
# SOC_counts   -0.098238    1.000000      0.982424
# Duration SUM -0.084718    0.982424      1.000000

# %%
sns.heatmap(corr, vmin=0, vmax=1, linecolor = 'grey', linewidths = .5, cmap="YlGnBu", xticklabels=corr.columns.values, yticklabels=corr.columns.values)
plt.show()

# %% [markdown]
# The resulting correlation on the count job tittles and how long it takes to process them indicates that they have a positive correlation.  It also provides evidence that job category (55) equal to WEB APPL/ENGINEER DEVELOPER is the job that most employeers are trying to fill. Thus, takes the longest processing time.
